# %%
import pandas as pd
import numpy as np
df=pd.read_csv('C:/Users/ROG/Desktop/DATA7901/wrangling.csv')
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=df.drop(columns=['Unnamed: 0','Unnamed: 0.1'])

# %%
df
# Out:
#      FlightNumber Rocket Booster Orbit       Date  Flights  GridFins  Reused  \
# 0               6       Falcon 9   LEO   2010/6/4        1     False   False
# 1               7       Falcon 9   LEO  2010/12/8        1     False   False
# 2               8       Falcon 9   LEO  2012/5/22        1     False   False
# 3               9       Falcon 9   ISS  2012/10/8        1     False   False
# 4              10       Falcon 9   ISS   2013/3/1        1     False   False
# ..            ...            ...   ...        ...      ...       ...     ...
# 174           181       Falcon 9  VLEO  2022/8/28        2      True    True
# 175           182       Falcon 9  VLEO  2022/8/31        7      True    True
# 176           183       Falcon 9  VLEO   2022/9/5        7      True    True
# 177           184       Falcon 9  VLEO  2022/9/11       14      True    True
# 178           185       Falcon 9  VLEO  2022/9/17        6      True    True
#
# ...

# %%
cor = df.corr()
plt.figure(figsize=(15, 15))
sns.heatmap(cor, annot=True, cmap=plt.cm.Reds)

plt.show()

# %%
sns.pairplot(df)
# Out:
# <__array_function__ internals>:180: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <__array_function__ internals>:180: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <__array_function__ internals>:180: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df[df['Outcome'].isin([1])]
# Out:
#      FlightNumber Rocket Booster  Orbit       Date  Flights  GridFins  Reused  \
# 8              14       Falcon 9    ISS 2014-04-18        1     False   False
# 9              15       Falcon 9    LEO 2014-07-14        1     False   False
# 14             20       Falcon 9  ES-L1 2015-02-11        1      True   False
# 19             25       Falcon 9    LEO 2015-12-22        1      True   False
# 22             28       Falcon 9    ISS 2016-04-08        1      True   False
# ..            ...            ...    ...        ...      ...       ...     ...
# 174           181       Falcon 9   VLEO 2022-08-28        2      True    True
# 175           182       Falcon 9   VLEO 2022-08-31        7      True    True
# 176           183       Falcon 9   VLEO 2022-09-05        7      True    True
# 177           184       Falcon 9   VLEO 2022-09-11       14      True    True
# 178           185       Falcon 9   VLEO 2022-09-17        6      True    True
#
# ...

# %%
df[].groupby(['Orbit','Outcome']).sum()
# Out:
#                FlightNumber  Flights  GridFins  Reused  Legs  Block  \
# Orbit Outcome
# ES-L1 1                  20        1         1       0     1    1.0
# GEO   1                 264        9         2       2     2   10.0
# GTO   0                 518       18         4       2     4   34.0
#       1                1390       43        20      12    20   81.0
# HCO   0                  55        1         1       0     1    3.0
# HEO   1                  60        1         1       0     1    4.0
# ISS   0                 297       11         5       2     5   19.0
#       1                2122       45        22      10    23   98.0
# LEO   0                  21        3         0       0     0    3.0
#       1                1174       48        11       7    12   48.0
# MEO   0                 154        2         1       0     1   10.0
#       1                 504        6         4       2     4   20.0
# PO    0                 157        6         3       2     2   10.0
# ...

# %%
df[['Orbit','Outcome']].groupby(['Orbit']).count()
# Out:
#        Outcome
# Orbit
# ES-L1        1
# GEO          2
# GTO         35
# HCO          1
# HEO          1
# ISS         32
# LEO         15
# MEO          6
# PO          14
# SO           1
# SSO         12
# TLI          2
# VLEO        57

# %%
group=df['Outcome'].groupby([df['Orbit'],df['Outcome']])
group.count()
# Out:
# Orbit  Outcome
# ES-L1  1           1
# GEO    1           2
# GTO    0          15
#        1          20
# HCO    0           1
# HEO    1           1
# ISS    0           9
#        1          23
# LEO    0           3
#        1          12
# MEO    0           2
#        1           4
# PO     0           4
#        1          10
# SO     0           1
# SSO    0           1
#        1          11
# TLI    1           2
# VLEO   0           3
#        1          54
# Name: Outcome, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(10, 7))

ax.bar(df['Orbit'], df[df['Outcome'].isin([1])], color="red", label="Success")

ax.bar(df['Orbit'], df[df['Outcome'].isin([0])], color="blue", bottom=df[df['Outcome'].isin([1])], label="Fail")


ax.set_title("Stacked Bar plot", fontsize=15)
ax.set_xlabel("Shops")
ax.set_ylabel("Product Sales")
ax.legend()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-86a061b19ddb> in <module>
#       1 fig, ax = plt.subplots(figsize=(10, 7))
#       2
# ----> 3 ax.bar(df['Orbit'], df[df['Outcome'].isin([1])], color="red", label="Success")
#       4
#       5 ax.bar(df['Orbit'], df[df['Outcome'].isin([0])], color="blue", bottom=df[df['Outcome'].isin([1])], label="Fail")
#
# I:\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1445     def inner(ax, *args, data=None, **kwargs):
#    1446         if data is None:
# -> 1447             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1448
#    1449         bound = new_sig.bind(ax, *args, **kwargs)
#
# I:\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in bar(self, x, height, width, bottom, align, **kwargs)
# ...

# %%
sns.factorplot(x=df[['Orbit','Outcome']],y='total_bill',hue='smoker',kind='bar',data=tips)
plt.show()

# %%
sns.countplot(x='Orbit',data=df)
# Out:
# <AxesSubplot:xlabel='Orbit', ylabel='count'>

# %%
sns.barplot(x='Orbit',y='FlightNumber',hue='Outcome',data=df)
# Out:
# <AxesSubplot:xlabel='Orbit', ylabel='FlightNumber'>

# %%
df['Outcome']==1
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 174     True
# 175     True
# 176     True
# 177     True
# 178     True
# Name: Outcome, Length: 179, dtype: bool
